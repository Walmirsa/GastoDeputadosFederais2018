# %%
# Install dependencies
# !pip3 install -q numpy scipy
# !pip3 install --upgrade -q gspread

# %%
#Subir Arquivo
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e25fa9d4-0e40-49b8-8e4e-73efd247ab58" name="files[]" multiple disabled />
#      <output id="result-e25fa9d4-0e40-49b8-8e4e-73efd247ab58">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Ano-2018.csv to Ano-2018.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import csv

sns.set(style="whitegrid")
# %matplotlib inline

deputados = pd.read_csv('Ano-2018.csv',sep=';',encoding='utf-8',quoting=csv.QUOTE_NONE)

#visualizar valores 
#deputados.shape
#deputados.columns
#deputados.info()

#Convertendo campos para valores
deputados['vlrGlosa'] = deputados['vlrGlosa'].str.replace(',','.').astype('float')
deputados['vlrDocumento'] = deputados['vlrDocumento'].str.replace(',','.').astype('float')
deputados['vlrLiquido'] = deputados['vlrLiquido'].str.replace(',','.').astype('float')
deputados['txtCNPJCPF'] = deputados['txtCNPJCPF'].astype(str)

#visualizar dados faltantes
#plt.figure(figsize=(15,5))
#sns.heatmap(deputados.isnull(), yticklabels=False, cbar=False, cmap='viridis')


#COntar
#deputados['txNomeParlamentar'].nunique()

"""
#Grafico por estado 
n_dep = pd.DataFrame(deputados.groupby('sgUF')['txNomeParlamentar'].nunique())
plt.figure(figsize=(15,5))
x = sns.barplot(x=n_dep.index,y='txNomeParlamentar', data=n_dep)
x.set(xlabel = 'Estados', ylabel = 'Números de Deputados')
"""

#total geral
soma_total = round(sum(deputados['vlrLiquido']),2)
soma_total

#Por tipo de gasto 
gastos_por_desc=pd.DataFrame(deputados.groupby('txtDescricao')['vlrLiquido'].sum())
gastos_por_desc.sort_values('vlrLiquido',ascending=False, inplace=True)
gastos_por_desc['vlrLiquido']=round(gastos_por_desc['vlrLiquido'],2)
gastos_por_desc['%'] = round(gastos_por_desc['vlrLiquido'] / soma_total  * 100,2)
gastos_por_desc

#Por tipo de palarmentar 
gastos_por_dep=pd.DataFrame(deputados.groupby('txNomeParlamentar')['vlrLiquido'].sum())
gastos_por_dep.sort_values('vlrLiquido',ascending=False, inplace=True)
gastos_por_dep['vlrLiquido']=round(gastos_por_dep['vlrLiquido'],2)
gastos_por_dep['%'] = round(gastos_por_dep['vlrLiquido'] / soma_total  * 100,2)
gastos_por_dep


#deputados.columns
# Out:
#                             vlrLiquido     %
# txNomeParlamentar
# JOSE STÉDILE                 447768.64  0.29
# PEDRO FERNANDES              447122.29  0.29
# RAFAEL MOTTA                 441745.27  0.29
# VICENTINHO JÚNIOR            438634.98  0.28
# VICTOR MENDES                436992.25  0.28
# JOZI ARAÚJO                  436567.15  0.28
# JÉSSICA SALES                433540.40  0.28
# ADALBERTO CAVALCANTI         426913.92  0.28
# RONALDO LESSA                422760.01  0.27
# GONZAGA PATRIOTA             420020.35  0.27
# ANGELIM                      418783.31  0.27
# JOSÉ REINALDO                418668.36  0.27
# JUNIOR MARRECA               418004.65  0.27
# CAJAR NARDES                 416370.28  0.27
# CABUÇU BORGES                414759.77  0.27
# ZECA CAVALCANTI              413556.86  0.27
# RODRIGO MARTINS              412515.43  0.27
# BETINHO GOMES                411232.44  0.27
# JUSCELINO FILHO              408229.08  0.26
# NELSON MEURER                407802.05  0.26
# MARIA HELENA                 406830.04  0.26
# WLADIMIR COSTA               406624.24  0.26
# FLAVIANO MELO                404162.92  0.26
# SILVIO COSTA                 403455.97  0.26
# JOÃO MARCELO SOUZA           401576.00  0.26
# ODORICO MONTEIRO             401471.44  0.26
# DANILO FORTE                 401277.00  0.26
# JOSÉ OTÁVIO GERMANO          398751.84  0.26
# JHONATAN DE JESUS            398101.86  0.26
# VANDER LOUBET                397086.67  0.26
# ...                                ...   ...
# MAURO PEREIRA                 67265.64  0.04
# MARX BELTRÃO                  67144.16  0.04
# XUXU DAL MOLIN                62655.40  0.04
# FELIPE CARRERAS               61667.98  0.04
# ARIOSTO HOLANDA               60765.48  0.04
# TIRIRICA                      59639.53  0.04
# PODE                          58955.73  0.04
# MARCIO ALVINO                 56481.75  0.04
# OSVALDO MAFRA                 56222.95  0.04
# REJANE DIAS                   55135.21  0.04
# JOÃO RODRIGUES                50347.08  0.03
# JOSÉ FOGAÇA                   50116.57  0.03
# SDD                           37704.77  0.02
# PROS                          32947.57  0.02
# WILSON BESERRA                31747.77  0.02
# FREIRE JÚNIOR                 30985.25  0.02
# JORGE BOEIRA                  28916.11  0.02
# IZAQUE SILVA                  27233.57  0.02
# MAURÍCIO QUINTELLA LESSA      24680.97  0.02
# PSOL                          16160.00  0.01
# PSD                           14002.00  0.01
# DEM                           12236.65  0.01
# LID.GOV-CD                     9882.33  0.01
# ERON BEZERRA                   8667.36  0.01
# PROFESSOR PACCO                6345.11  0.00
# LID.GOV-CN                     3329.16  0.00
# AVANTE                         1781.02  0.00
# PHS                             920.83  0.00
# FREITAS DO PT                   313.76  0.00
# WASHINGTON CORAÇÃO VALENTE        7.70  0.00
#
# [567 rows x 2 columns]
